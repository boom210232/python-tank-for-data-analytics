# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sn

# Generating random data


data = pd.read_csv('heart.csv')
# data = data.dropna(subset=['Age', 'Fare'])
# Visualizing the random data
plt.scatter(data['chol'], data['thalachh'])
plt.title('Random Data')
plt.xlabel('Feature1')
plt.ylabel('Feature2')
plt.show()

# %%
# Preprocessing data
X = data[['chol', 'thalachh']]

# Applying k-means clustering with k=3 (you can choose a different value for k)
kmeans = KMeans(n_clusters=6, random_state=42)
data['Cluster'] = kmeans.fit_predict(X)

# Visualizing the clusters
plt.scatter(data['chol'], data['thalachh'], c=data['Cluster'], cmap='viridis')
plt.title('K-Means Clustering')
plt.xlabel('cholesterol')
plt.ylabel('maximum heart rate achieved')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='red', marker='X', label='Centroids')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Preprocessing data
X = data[['trtbps', 'thalachh']]

# Applying k-means clustering with k=3 (you can choose a different value for k)
kmeans = KMeans(n_clusters=6, random_state=42)
data['Cluster'] = kmeans.fit_predict(X)

# Visualizing the clusters
plt.scatter(data['trtbps'], data['thalachh'], c=data['Cluster'], cmap='viridis')
plt.title('K-Means Clustering')
plt.xlabel('resting blood pressure (in mm Hg)')
plt.ylabel('maximum heart rate achieved')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='red', marker='X', label='Centroids')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
from sklearn.metrics import silhouette_score

silhouette_avg = silhouette_score(X, kmeans.labels_)

print("Silhouette score is: ", silhouette_avg)
# Out:
# Silhouette score is:  0.3427624555319919

# %%
from sklearn.cluster import KMeans

kmeans.fit(X)
inertia = kmeans.inertia_
print("The sum of distances of all the points within a cluster from the centroid of that cluster is:" , inertia)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# The sum of distances of all the points within a cluster from the centroid of that cluster is: 54352.51746273221

# %%
# Preprocessing data
X = data[['trtbps', 'chol']]

# Applying k-means clustering with k=3 (you can choose a different value for k)
kmeans = KMeans(n_clusters=6, random_state=42)
data['Cluster'] = kmeans.fit_predict(X)

# Visualizing the clusters
plt.scatter(data['chol'], data['trtbps'], c=data['Cluster'], cmap='viridis')
plt.title('K-Means Clustering')
plt.xlabel('Cholesterol')
plt.ylabel('resting blood pressure (in mm Hg)')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='red', marker='X', label='Centroids')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
corr_matrix = data.corr()
print(corr_matrix)
fig, ax = plt.subplots(figsize=(10,10))
sn.heatmap(corr_matrix, annot=True)
# Out:
#                age       sex        cp    trtbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trtbps    0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalachh -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exng      0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slp      -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# caa       0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thall     0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
# Preprocessing data
X = data[['trtbps', 'chol' , 'thalachh']]

# Finding the optimal number of clusters using the elbow method
inertia_values = []
possible_k_values = range(1, 11)  # You can adjust the range based on your dataset and requirements

for k in possible_k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    inertia_values.append(kmeans.inertia_)

# Finding the elbow point (optimal k)
optimal_k = np.argmin(np.diff(inertia_values)) + 1

# Plotting the elbow curve
plt.plot(possible_k_values, inertia_values, marker='o')
plt.title('Elbow Method for Optimal K')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Inertia (Within-Cluster Sum of Squares)')
plt.show()

# Printing the optimal k value
print(f'Best K is: {optimal_k}')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage


# Preprocessing data
X = data[['trtbps', 'thalachh']]

# Performing hierarchical clustering
agglomerative_cluster = AgglomerativeClustering(n_clusters=None, distance_threshold=0, linkage='ward')
agglomerative_cluster.fit(X)

# Plotting the dendrogram
linkage_matrix = linkage(X, method='ward')
dendrogram(linkage_matrix)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('resting blood pressure (in mm Hg)')
plt.ylabel('maximum heart rate achieved')
plt.show()

# Plotting the clustered data
plt.scatter(data['trtbps'], data['thalachh'], c=agglomerative_cluster.labels_, cmap='viridis')
plt.title('Hierarchical Clustering')
plt.xlabel('trtbps')
plt.ylabel('thalachh')
plt.show()
